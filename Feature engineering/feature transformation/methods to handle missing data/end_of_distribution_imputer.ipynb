# %% [markdown]
# # choose the values which are present at the end of distribution
#
# # for normal distribution use value = mean+3*sigma or mean-3*sigma
# # for skewed distribution  = use iqr proximity rule(q1-1.5iqr) or (q3+1.5iqr)
