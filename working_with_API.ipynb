# %%
import pandas as pd

# %%
import requests

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
API_KEY = "66bdb6973e4e0badaed5cd5ac264d110"

# %%
response = requests.get('https://api.themoviedb.org/3//movie/top_rated?language=en-US&page=1&region=AT&api_key=66bdb6973e4e0badaed5cd5ac264d110')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
# ...

# %%
response.json()['results']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response.json()['results']
#
# KeyError: 'results'

# %% [markdown]
# ## now converting this list into dataframe

# %%
df=pd.DataFrame(response.json()['results'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=pd.DataFrame(response.json()['results'])
#
# KeyError: 'results'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
temp_df = pd.DataFrame(response.json()['results']).head(2)[['id','title','overview','release_date','vote_average','vote_count']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 temp_df = pd.DataFrame(response.json()['results']).head(2)[['id','title','overview','release_date','vote_average','vote_count']]
#
# KeyError: 'results'

# %%
temp_df
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
#
#                                             overview release_date  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23
#
#    vote_average  vote_count
# 0         8.978        1597
# 1         8.722       30498

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # run this code in loop
# # loop = no. of pages

# %%
df = pd.DataFrame()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
for i in range(1,546):
    response = requests.get('https://api.themoviedb.org/3//movie/top_rated?language=en-US&region=AT&api_key=66bdb6973e4e0badaed5cd5ac264d110&page={}.format(i)')
    temp_df = pd.DataFrame(response.json()['results']).head(2)[['id','title','overview','release_date','vote_average','vote_count']]
    df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.shape
# Out:
# (0, 0)

# %%
df.to_csv('movies.csv')
