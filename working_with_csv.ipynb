# %% [markdown]
# # importing pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('placement.csv')
df

# %%
import requests
from io import StringIO
url = "https://github.com/campusx-official/placement-project-logistic-regression/blob/main/end_to_end_ml.ipynb"
headers = {"User-Agent": "Mozilla/5.0(Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.geet(url,headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
